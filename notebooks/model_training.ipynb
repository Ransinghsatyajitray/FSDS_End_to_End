# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data\\gemstone.csv')

# %%
data.drop(labels=["id"], axis = 1, inplace =True)

# %%
data
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
X = data.drop(labels=["price"], axis=1)

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
y = data[["price"]]

# %%
import pandas as pd

# Sample DataFrame
data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
df = pd.DataFrame(data)

# Keep only column 'A'
df = df.loc[:, ~df.columns.isin(['B', 'C'])] 

# OR using the column name directly
df = df.loc[:,~df.columns.str.match('B|C')]


print(df)
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
X.select_dtypes(include="object")
# Out:
#               cut color clarity
# 0         Premium     F     VS2
# 1       Very Good     J     SI2
# 2           Ideal     G     VS1
# 3           Ideal     G     VS1
# 4         Premium     G     VS2
# ...           ...   ...     ...
# 193568      Ideal     D    VVS2
# 193569    Premium     G    VVS2
# 193570  Very Good     F     SI1
# 193571  Very Good     D     SI1
# 193572       Good     E     SI2
#
# [193573 rows x 3 columns]

# %%
X.select_dtypes(include="object").columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
X.select_dtypes(exclude="object").columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
X.get("cut").unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_categories = ['Premium', 'Very Good', 'Ideal', 'Good', 'Fair']
cut_categories.sort()

# %%
cut_categories
# Out:
# ['Fair', 'Good', 'Ideal', 'Premium', 'Very Good']

# %%
X.get("color").unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_categories = ['F', 'J', 'G', 'E', 'D', 'H', 'I']

# %%
X.get("clarity").unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_categories = ['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1']

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder

# pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
num_pipeline = Pipeline(
    
    steps=[
        ('imputer',SimpleImputer()),
        ('scalar', StandardScaler())
        
    ]
)

# %%
cat_pipeline = Pipeline(
    
    steps=[
        ('impute', SimpleImputer(strategy="most_frequent")),
        ('ordinalencoder', OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories]))
    ]
)

# %%
numerical_cols = X.select_dtypes(exclude="object").columns

# %%
categorical_cols = X.select_dtypes(include="object").columns

# %%
preprocessing = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_cols),
        ("cat_pipeline", cat_pipeline, categorical_cols)
    ]
)

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=30)

# %%
preprocessing.fit_transform(X_train)
# Out:
# array([[-0.97543926, -0.84960654, -0.12153081, ...,  2.        ,
#          6.        ,  5.        ],
#        [ 0.2351953 ,  1.83363716, -0.12153081, ...,  1.        ,
#          3.        ,  3.        ],
#        [ 0.49461699,  0.81585507,  0.39980029, ...,  3.        ,
#          2.        ,  2.        ],
#        ...,
#        [ 0.45138004,  1.55606023, -0.6428619 , ...,  1.        ,
#          2.        ,  3.        ],
#        [ 0.66756478, -1.77486298,  1.44246248, ...,  2.        ,
#          2.        ,  2.        ],
#        [ 0.25681377,  0.81585507, -0.12153081, ...,  2.        ,
#          2.        ,  3.        ]])

# %%
preprocessing.get_feature_names_out()
# Out:
# array(['num_pipeline__carat', 'num_pipeline__depth',
#        'num_pipeline__table', 'num_pipeline__x', 'num_pipeline__y',
#        'num_pipeline__z', 'cat_pipeline__cut', 'cat_pipeline__color',
#        'cat_pipeline__clarity'], dtype=object)

# %%
X_train
# Out:
#         carat      cut color clarity  depth  table     x     y     z
# 168192   0.34    Ideal     I    VVS2   60.9   57.0  4.56  4.53  2.76
# 35202    0.90     Good     E     SI1   63.8   57.0  6.07  6.03  3.87
# 41091    1.02  Premium     G     VS1   62.7   58.0  6.35  6.39  4.00
# 31239    0.32  Premium     G     VS2   62.1   59.0  4.37  4.35  2.71
# 45722    0.35    Ideal     J    VVS2   61.1   56.0  4.53  4.57  2.78
# ...       ...      ...   ...     ...    ...    ...   ...   ...   ...
# 66455    0.31    Ideal     E     SI1   61.8   56.0  4.31  4.35  2.68
# 46220    1.25    Ideal     G     SI2   62.0   56.0  6.88  6.95  4.28
# 98804    1.00     Good     G     SI1   63.5   56.0  6.29  6.37  4.02
# 48045    1.10    Ideal     G     VS1   59.9   60.0  6.68  6.77  4.01
# 169765   0.91    Ideal     G     SI1   62.7   57.0  6.14  6.18  3.86
#
# [135501 rows x 9 columns]

# %%
X_train = pd.DataFrame(preprocessing.fit_transform(X_train), columns=preprocessing.get_feature_names_out()) # preprocessing.fit_transform(X_train) does the same thing
X_test = pd.DataFrame(preprocessing.fit_transform(X_test), columns=preprocessing.get_feature_names_out())

# %%
X_train
# Out:
#         num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                 -0.975439            -0.849607            -0.121531
# 1                  0.235195             1.833637            -0.121531
# 2                  0.494617             0.815855             0.399800
# 3                 -1.018676             0.260701             0.921131
# 4                 -0.953821            -0.664555            -0.642862
# ...                     ...                  ...                  ...
# 135496            -1.040295            -0.016876            -0.642862
# 135497             0.991842             0.168176            -0.642862
# 135498             0.451380             1.556060            -0.642862
# 135499             0.667565            -1.774863             1.442462
# 135500             0.256814             0.815855            -0.121531
#
#         num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0             -1.042757        -1.080970        -1.123150                2.0
# 1              0.318447         0.279859         0.485354                1.0
# 2              0.570855         0.606458         0.673737                3.0
# 3             -1.214034        -1.244270        -1.195605                3.0
# 4             -1.069801        -1.044681        -1.094168                2.0
# ...                 ...              ...              ...                ...
# 135496        -1.268122        -1.244270        -1.239078                2.0
# 135497         1.048629         1.114501         1.079486                2.0
# 135498         0.516768         0.588314         0.702719                1.0
# 135499         0.868337         0.951202         0.688228                2.0
# 135500         0.381549         0.415942         0.470863                2.0
#
#         cat_pipeline__color  cat_pipeline__clarity
# 0                       6.0                    5.0
# 1                       3.0                    3.0
# 2                       2.0                    2.0
# 3                       2.0                    0.0
# 4                       1.0                    5.0
# ...                     ...                    ...
# 135496                  3.0                    3.0
# 135497                  2.0                    1.0
# 135498                  2.0                    3.0
# 135499                  2.0                    2.0
# 135500                  2.0                    3.0
#
# [135501 rows x 9 columns]

# %%
X_test
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                -0.560473            -0.946668            -0.632686
# 1                -0.171673             0.990913            -0.111947
# 2                -1.057274             0.252787            -0.111947
# 3                 0.973129            -0.208542             1.971009
# 4                -0.927674            -1.315731             0.408792
# ...                    ...                  ...                  ...
# 58067             1.016329             1.175444            -0.632686
# 58068            -0.992474             0.252787            -1.153426
# 58069            -0.193273            -3.345577             1.450270
# 58070            -0.819674            -0.208542            -0.111947
# 58071             2.614731            -0.762136             1.450270
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0            -0.425330        -0.459668        -0.498885                3.0
# 1            -0.037825        -0.024281         0.040318                4.0
# 2            -1.299471        -1.294159        -1.271258                2.0
# 3             1.052598         1.000693         0.987567                3.0
# 4            -1.002083        -0.985760        -1.067235                3.0
# ...                ...              ...              ...                ...
# 58067         1.007539         1.046046         1.162444                4.0
# 58068        -1.137259        -1.121819        -1.110954                2.0
# 58069         0.106363         0.075496        -0.221997                3.0
# 58070        -0.848883        -0.876913        -0.877785                2.0
# 58071         2.143021         2.043808         2.022254                3.0
#
#        cat_pipeline__color  cat_pipeline__clarity
# 0                      3.0                    0.0
# 1                      5.0                    3.0
# 2                      5.0                    4.0
# 3                      2.0                    0.0
# 4                      3.0                    2.0
# ...                    ...                    ...
# 58067                  5.0                    0.0
# 58068                  0.0                    6.0
# 58069                  1.0                    0.0
# 58070                  2.0                    3.0
# 58071                  1.0                    0.0
#
# [58072 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error


## Train multiple models
models = {
    'LinearRegression':LinearRegression(),
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'Elasticnet': ElasticNet()
}


trained_model_list = []
model_list = []
r2_list = []

for i in range(len(list(models))):
    model = list(models.values())[i]

# %%
model
# Out:
# ElasticNet()

# %%
models
# Out:
# {'LinearRegression': LinearRegression(),
#  'Lasso': Lasso(),
#  'Ridge': Ridge(),
#  'Elasticnet': ElasticNet()}

# %%
models.keys()
# Out:
# dict_keys(['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet'])

# %%
models.values()
# Out:
# dict_values([LinearRegression(), Lasso(), Ridge(), ElasticNet()])

# %%
for i in range(len(list(models))):
    model = list(models.values())[i]
    print(model)
# Out:
# LinearRegression()
# Lasso()
# Ridge()
# ElasticNet()

# %%
list(models.values())[1]
# Out:
# Lasso()

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error


import numpy as np

def evaluate_model(true, predicted):
    mae= mean_absolute_error(true, predicted)
    mse= mean_squared_error(true, predicted)
    rmse= np.sqrt(mean_squared_error(true,predicted))
    r2_square=r2_score(true,predicted)
    return mae, rmse, r2_square


## Train multiple models
models = {
    'LinearRegression':LinearRegression(),
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'Elasticnet': ElasticNet()
}


trained_model_list = []
model_list = []
r2_list = []

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train)
    
    # make prediction
    y_pred = model.predict(X_test)
    mae, rmse, r2_square = evaluate_model(y_test, y_pred)
    
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print('Model Training Performance')
    print("RMSE", rmse)
    print("MAE", mae)
    print("R2 score", r2_square*100)
    
    r2_list.append(r2_square)
    print("="*35)
# Out:
# LinearRegression
# Model Training Performance
# RMSE 1198.8949497574974
# MAE 726.5972746958934
# R2 score 91.1761018866006
# ===================================
# Lasso
# Model Training Performance
# RMSE 1198.7860021049198
# MAE 728.0460907285411
# R2 score 91.17770552886464
# ===================================
# Ridge
# Model Training Performance
# RMSE 1198.896162952062
# MAE 726.6254643965193
# R2 score 91.17608402830426
# ===================================
# Elasticnet
# Model Training Performance
# RMSE 1629.3839885740244
# MAE 1136.9703159589371
# R2 score 83.70159475596266
# ===================================
